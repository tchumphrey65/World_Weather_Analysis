# %%
# Import the dependencies.
import pandas as pd
import gmaps
import gmaps.datasets
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df
# Out:
#      City_ID                City Country                 Date      Lat  \
# 0          0             Camacha      PT  2021-12-22 01:38:38  33.0833
# 1          1         Port Alfred      ZA  2021-12-22 01:38:38 -33.5906
# 2          2       Shahr-E Babak      IR  2021-12-22 01:38:38  30.1165
# 3          3              Hobart      AU  2021-12-22 01:38:39 -42.8794
# 4          4              Torbay      CA  2021-12-22 01:35:28  47.6666
# ..       ...                 ...     ...                  ...      ...
# 553      553        Ornskoldsvik      SE  2021-12-22 01:53:15  63.2909
# 554      554  Severo-Yeniseyskiy      RU  2021-12-22 01:53:15  60.3725
# 555      555         Santa Maria      BR  2021-12-22 01:53:15 -29.6842
# 556      556              Ouesso      CG  2021-12-22 01:53:16   1.6136
# 557      557              Igarka      RU  2021-12-22 01:53:16  67.4667
#
#           Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# ...

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.

print(api_key)
g_key ="AIzaSyA6GKirnmigACl-6_SKmu2-M3Pa_2rRaXM"
api_key=g_key
print(api_key==g_key)
gmaps.configure(api_key=g_key)
# Out:
# AIzaSyA6GKirnmigACl-6_SKmu2-M3Pa_2rRaXM
# True

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
temps
# Out:
# [62.53,
#  68.2,
#  44.78,
#  64.11,
#  34.75,
#  75.18,
#  2.16,
#  77.5,
#  53.78,
#  47.86,
#  74.93,
#  12.31,
#  40.32,
#  27.55,
#  51.91,
#  0,
#  81.1,
#  87.96,
#  1.13,
#  0,
#  0,
#  77.59,
#  73.58,
#  44.67,
#  75.04,
#  30.56,
#  10.02,
#  42.71,
#  78.93,
#  14.02,
#  38.34,
#  25.63,
#  70.27,
#  41.95,
#  33.01,
#  55.29,
#  59.76,
#  60.08,
#  37.9,
#  21.15,
#  81.75,
#  38.07,
#  70.93,
#  22.87,
#  0,
#  81.5,
#  81.28,
#  79.05,
#  1.42,
#  0,
#  67.87,
#  78.8,
#  57.15,
#  65.61,
#  65.34,
#  70.14,
#  0,
#  0,
#  82.8,
#  32.31,
#  33.85,
#  0,
#  75.27,
#  64.47,
#  15.8,
#  49.64,
#  72.82,
#  65.01,
#  15.93,
#  0,
#  72.97,
#  77.02,
#  30.36,
#  81.93,
#  77.0,
#  74.39,
#  76.39,
#  55.81,
#  63.75,
#  58.95,
#  60.89,
#  0,
#  52.14,
#  76.98,
#  34.12,
#  35.91,
#  32.92,
#  4.32,
#  79.59,
#  24.93,
#  72.28,
#  31.95,
#  27.84,
#  15.71,
#  33.1,
#  46.62,
#  79.18,
#  79.09,
#  3.74,
#  25.41,
#  73.74,
#  0,
#  84.09,
#  65.46,
#  0,
#  36.86,
# ...

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
##heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
# Add the heatmap layer.
##fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps
gmaps.configure(api_key=g_key)
new_york_coordinates = (80.75, -74.00)

# %%
figure = gmaps.figure(center=new_york_coordinates,zoom_level=12)

# %%
figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
print(figure)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Past into Browser with my API

https://maps.googleapis.com/maps/api/staticmap?center=Brooklyn+Bridge,New+York,NY&zoom=13&size=600x300&maptype=roadmap
&markers=color:blue%7Clabel:S%7C40.702147,-74.015794&markers=color:green%7Clabel:G%7C40.711614,-74.012318
&markers=color:red%7Clabel:C%7C40.718217,-73.998284
&key=AIzaSyA6GKirnmigACl-6_SKmu2-M3Pa_2rRaXM
# Out:
#   File "C:\Users\Tim\AppData\Local\Temp/ipykernel_24404/1515832017.py", line 3
#     https://maps.googleapis.com/maps/api/staticmap?center=Brooklyn+Bridge,New+York,NY&zoom=13&size=600x300&maptype=roadmap
#            ^
# SyntaxError: invalid syntax
